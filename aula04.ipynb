# %% [markdown]
# <a href="https://colab.research.google.com/github/wagnermor/algebraLinear-Ada/blob/main/aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from plot_helper import *

# %%
# Vetores e suas transformações (transformações lineares)

vetor = [(2,2)]

origens = [(0,-1), (0,1), (0,0), (0,2),(-1,4)]

plot_vector(vetor, origens)

pyplot.title('Um vetor com diferentes origens')
# Out:
# Text(0.5, 1.0, 'Um vetor com diferentes origens')

# %%
import numpy
# Base canonica (i, j, k)

i = numpy.array((1,0))
j = numpy.array((0,1))

vetores = [i,j]

plot_vector(vetores)
pyplot.title('Base canonica')
# Out:
# Text(0.5, 1.0, 'Base canonica')

# %%
vetores = [i, j, (4 * i), (3 * j), (4 * i + 3 * j)]

plot_vector(vetores)

pyplot.title('Vetor na base canonica')
# Out:
# Text(0.5, 1.0, 'Vetor na base canonica')
